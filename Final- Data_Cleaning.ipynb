# %% [markdown]
# # **Introduction**

# %% [markdown]
# Initial step is for us to export BigQuery Data from GCP by running a query to divide the large dataset into chunks and exporting it to google drive as JSON files.
#
# For this project we will be using Google Collab as it makes processing such large dataset easier. We mount our local google drive and using pyspark API we will start cleaning this dataset.

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.2.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 47 kB/s
# Collecting py4j==0.10.9.3
#   Downloading py4j-0.10.9.3-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 66.6 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.1-py2.py3-none-any.whl size=281853642 sha256=5eb6b4d9e38673f4a1051abc0b4612843fceaddd6f1b8026ca4ad35d04e38011
#   Stored in directory: /root/.cache/pip/wheels/9f/f5/07/7cd8017084dce4e93e84e92efd1e1d5334db05f2e83bcef74f
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.3 pyspark-3.2.1

# %% [markdown]
# # **2.1: Imports**

# %% [markdown]
# **We need to import all the predict libaries we will need and mount personal google drive where we saved the json files to extract into google colab**

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
import pandas as pd 
import matplotlib.pyplot as plt
import random
from pyspark.sql.functions import col
from pyspark.sql.types import StringType,BooleanType,DateType, StructType
from pyspark.sql.functions import split
from pyspark.sql.functions import *

# %%
spark = SparkSession.builder.appName('Project').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://701b9536d18b:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Project</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = spark.read.option("multiline","false").json("/content/drive/MyDrive/BigQuery_Edata")

# %%
df.show(n=10)
# Out:
# +---------------+--------------------+--------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+-----------+--------------+
# |channelGrouping|    customDimensions|    date|              device|      fullVisitorId|          geoNetwork|                hits|socialEngagementType|              totals|       trafficSource|   visitId|visitNumber|visitStartTime|
# +---------------+--------------------+--------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+-----------+--------------+
# |       Referral|[{4, North America}]|20170531|{Chrome, not avai...|5988717949752143819|{New York, not av...|[{{shop.googlemer...|Not Socially Engaged|{null, 5, null, 5...|{null, {null, not...|1496250487|          3|    1496250487|
# |       Referral|                  []|20170531|{Chrome, not avai...|1914206347497291855|{(not set), not a...|[{{shop.googlemer...|Not Socially Engaged|{null, 7, null, 7...|{null, {null, not...|1496242570|          7|    1496242570|
# |       Referral|[{4, North America}]|20170531|{Chrome, not avai...|5688612779726117211|{New York, not av...|[{{shop.googlemer...|Not Socially Engaged|{null, 8, null, 8...|{null, {null, not...|1496268814|          2|    1496268814|
# |         Direct|[{4, South America}]|20170531|{Chrome, not avai...|5995173173416756249|{Santa Fe, not av...|[{{shop.googlemer...|Not Socially Engaged|{null, 10, null, ...|{null, {null, not...|1496260952|          2|    1496260952|
# |       Referral|[{4, North America}]|20170531|{Chrome, not avai...|5703962423814396269|{Los Angeles, not...|[{{shop.googlemer...|Not Socially Engaged|{null, 39, null, ...|{null, {null, not...|1496262254|         22|    1496262254|
# | Organic Search|[{4, North America}]|20170531|{Firefox, not ava...|1192333145578267748|{Toronto, not ava...|[{{shop.googlemer...|Not Socially Engaged|{null, 80, null, ...|{null, {null, not...|1496280352|          2|    1496280352|
# |         Direct|[{4, North America}]|20170531|{Safari, not avai...|0423250391712266292|{Sunnyvale, not a...|[{{www.googlemerc...|Not Socially Engaged|{1, 1, null, 1, n...|{null, {null, not...|1496242282|          2|    1496242282|
# | Organic Search|         [{4, EMEA}]|20170531|{Chrome, not avai...|5476517208251322333|{London, not avai...|[{{www.googlemerc...|Not Socially Engaged|{1, 1, 1, 1, null...|{null, {null, not...|1496242202|          1|    1496242202|
# | Organic Search|         [{4, EMEA}]|20170531|{Chrome, not avai...|7457135857298103204|{(not set), not a...|[{{www.googlemerc...|Not Socially Engaged|{1, 1, 1, 1, null...|{null, {null, not...|1496227837|          1|    1496227837|
# | Organic Search|         [{4, EMEA}]|20170531|{Firefox, not ava...|4500406506454646175|{Berlin, not avai...|[{{www.googlemerc...|Not Socially Engaged|{1, 1, null, 1, n...|{null, {null, not...|1496240339|          7|    1496240339|
# +---------------+--------------------+--------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+-----------+--------------+
# only showing top 10 rows

# %% [markdown]
# #### Identify dtype of each substructure

# %%
df.printSchema()
# Out:
# root
#  |-- channelGrouping: string (nullable = true)
#  |-- customDimensions: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- index: string (nullable = true)
#  |    |    |-- value: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- device: struct (nullable = true)
#  |    |-- browser: string (nullable = true)
#  |    |-- browserSize: string (nullable = true)
#  |    |-- browserVersion: string (nullable = true)
#  |    |-- deviceCategory: string (nullable = true)
#  |    |-- flashVersion: string (nullable = true)
#  |    |-- isMobile: boolean (nullable = true)
#  |    |-- language: string (nullable = true)
#  |    |-- mobileDeviceBranding: string (nullable = true)
#  |    |-- mobileDeviceInfo: string (nullable = true)
#  |    |-- mobileDeviceMarketingName: string (nullable = true)
#  |    |-- mobileDeviceModel: string (nullable = true)
#  |    |-- mobileInputSelector: string (nullable = true)
#  |    |-- operatingSystem: string (nullable = true)
#  |    |-- operatingSystemVersion: string (nullable = true)
#  |    |-- screenColors: string (nullable = true)
#  |    |-- screenResolution: string (nullable = true)
#  |-- fullVisitorId: string (nullable = true)
#  |-- geoNetwork: struct (nullable = true)
#  |    |-- city: string (nullable = true)
#  |    |-- cityId: string (nullable = true)
#  |    |-- continent: string (nullable = true)
#  |    |-- country: string (nullable = true)
#  |    |-- latitude: string (nullable = true)
#  |    |-- longitude: string (nullable = true)
#  |    |-- metro: string (nullable = true)
#  |    |-- networkDomain: string (nullable = true)
#  |    |-- networkLocation: string (nullable = true)
#  |    |-- region: string (nullable = true)
#  |    |-- subContinent: string (nullable = true)
#  |-- hits: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- appInfo: struct (nullable = true)
#  |    |    |    |-- exitScreenName: string (nullable = true)
#  |    |    |    |-- landingScreenName: string (nullable = true)
#  |    |    |    |-- screenDepth: string (nullable = true)
#  |    |    |    |-- screenName: string (nullable = true)
#  |    |    |-- contentGroup: struct (nullable = true)
#  |    |    |    |-- contentGroup1: string (nullable = true)
#  |    |    |    |-- contentGroup2: string (nullable = true)
#  |    |    |    |-- contentGroup3: string (nullable = true)
#  |    |    |    |-- contentGroup4: string (nullable = true)
#  |    |    |    |-- contentGroup5: string (nullable = true)
#  |    |    |    |-- contentGroupUniqueViews1: string (nullable = true)
#  |    |    |    |-- contentGroupUniqueViews2: string (nullable = true)
#  |    |    |    |-- contentGroupUniqueViews3: string (nullable = true)
#  |    |    |    |-- previousContentGroup1: string (nullable = true)
#  |    |    |    |-- previousContentGroup2: string (nullable = true)
#  |    |    |    |-- previousContentGroup3: string (nullable = true)
#  |    |    |    |-- previousContentGroup4: string (nullable = true)
#  |    |    |    |-- previousContentGroup5: string (nullable = true)
#  |    |    |-- customDimensions: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- customMetrics: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- customVariables: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- dataSource: string (nullable = true)
#  |    |    |-- eCommerceAction: struct (nullable = true)
#  |    |    |    |-- action_type: string (nullable = true)
#  |    |    |    |-- option: string (nullable = true)
#  |    |    |    |-- step: string (nullable = true)
#  |    |    |-- eventInfo: struct (nullable = true)
#  |    |    |    |-- eventAction: string (nullable = true)
#  |    |    |    |-- eventCategory: string (nullable = true)
#  |    |    |    |-- eventLabel: string (nullable = true)
#  |    |    |-- exceptionInfo: struct (nullable = true)
#  |    |    |    |-- isFatal: boolean (nullable = true)
#  |    |    |-- experiment: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- hitNumber: string (nullable = true)
#  |    |    |-- hour: string (nullable = true)
#  |    |    |-- isEntrance: boolean (nullable = true)
#  |    |    |-- isExit: boolean (nullable = true)
#  |    |    |-- isInteraction: boolean (nullable = true)
#  |    |    |-- item: struct (nullable = true)
#  |    |    |    |-- currencyCode: string (nullable = true)
#  |    |    |    |-- transactionId: string (nullable = true)
#  |    |    |-- latencyTracking: struct (nullable = true)
#  |    |    |    |-- domContentLoadedTime: string (nullable = true)
#  |    |    |    |-- domInteractiveTime: string (nullable = true)
#  |    |    |    |-- domLatencyMetricsSample: string (nullable = true)
#  |    |    |    |-- domainLookupTime: string (nullable = true)
#  |    |    |    |-- pageDownloadTime: string (nullable = true)
#  |    |    |    |-- pageLoadSample: string (nullable = true)
#  |    |    |    |-- pageLoadTime: string (nullable = true)
#  |    |    |    |-- redirectionTime: string (nullable = true)
#  |    |    |    |-- serverConnectionTime: string (nullable = true)
#  |    |    |    |-- serverResponseTime: string (nullable = true)
#  |    |    |    |-- speedMetricsSample: string (nullable = true)
#  |    |    |-- minute: string (nullable = true)
#  |    |    |-- page: struct (nullable = true)
#  |    |    |    |-- hostname: string (nullable = true)
#  |    |    |    |-- pagePath: string (nullable = true)
#  |    |    |    |-- pagePathLevel1: string (nullable = true)
#  |    |    |    |-- pagePathLevel2: string (nullable = true)
#  |    |    |    |-- pagePathLevel3: string (nullable = true)
#  |    |    |    |-- pagePathLevel4: string (nullable = true)
#  |    |    |    |-- pageTitle: string (nullable = true)
#  |    |    |    |-- searchCategory: string (nullable = true)
#  |    |    |    |-- searchKeyword: string (nullable = true)
#  |    |    |-- product: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- customDimensions: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- customMetrics: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- isClick: boolean (nullable = true)
#  |    |    |    |    |-- isImpression: boolean (nullable = true)
#  |    |    |    |    |-- localProductPrice: string (nullable = true)
#  |    |    |    |    |-- localProductRevenue: string (nullable = true)
#  |    |    |    |    |-- productBrand: string (nullable = true)
#  |    |    |    |    |-- productListName: string (nullable = true)
#  |    |    |    |    |-- productListPosition: string (nullable = true)
#  |    |    |    |    |-- productPrice: string (nullable = true)
#  |    |    |    |    |-- productQuantity: string (nullable = true)
#  |    |    |    |    |-- productRevenue: string (nullable = true)
#  |    |    |    |    |-- productSKU: string (nullable = true)
#  |    |    |    |    |-- productVariant: string (nullable = true)
#  |    |    |    |    |-- v2ProductCategory: string (nullable = true)
#  |    |    |    |    |-- v2ProductName: string (nullable = true)
#  |    |    |-- promotion: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- promoCreative: string (nullable = true)
#  |    |    |    |    |-- promoId: string (nullable = true)
#  |    |    |    |    |-- promoName: string (nullable = true)
#  |    |    |    |    |-- promoPosition: string (nullable = true)
#  |    |    |-- promotionActionInfo: struct (nullable = true)
#  |    |    |    |-- promoIsClick: boolean (nullable = true)
#  |    |    |    |-- promoIsView: boolean (nullable = true)
#  |    |    |-- publisher_infos: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- referer: string (nullable = true)
#  |    |    |-- social: struct (nullable = true)
#  |    |    |    |-- hasSocialSourceReferral: string (nullable = true)
#  |    |    |    |-- socialInteractionNetworkAction: string (nullable = true)
#  |    |    |    |-- socialNetwork: string (nullable = true)
#  |    |    |-- time: string (nullable = true)
#  |    |    |-- transaction: struct (nullable = true)
#  |    |    |    |-- affiliation: string (nullable = true)
#  |    |    |    |-- currencyCode: string (nullable = true)
#  |    |    |    |-- localTransactionRevenue: string (nullable = true)
#  |    |    |    |-- localTransactionShipping: string (nullable = true)
#  |    |    |    |-- localTransactionTax: string (nullable = true)
#  |    |    |    |-- transactionCoupon: string (nullable = true)
#  |    |    |    |-- transactionId: string (nullable = true)
#  |    |    |    |-- transactionRevenue: string (nullable = true)
#  |    |    |    |-- transactionShipping: string (nullable = true)
#  |    |    |    |-- transactionTax: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- socialEngagementType: string (nullable = true)
#  |-- totals: struct (nullable = true)
#  |    |-- bounces: string (nullable = true)
#  |    |-- hits: string (nullable = true)
#  |    |-- newVisits: string (nullable = true)
#  |    |-- pageviews: string (nullable = true)
#  |    |-- sessionQualityDim: string (nullable = true)
#  |    |-- timeOnSite: string (nullable = true)
#  |    |-- totalTransactionRevenue: string (nullable = true)
#  |    |-- transactionRevenue: string (nullable = true)
#  |    |-- transactions: string (nullable = true)
#  |    |-- visits: string (nullable = true)
#  |-- trafficSource: struct (nullable = true)
#  |    |-- adContent: string (nullable = true)
#  |    |-- adwordsClickInfo: struct (nullable = true)
#  |    |    |-- adNetworkType: string (nullable = true)
#  |    |    |-- criteriaParameters: string (nullable = true)
#  |    |    |-- gclId: string (nullable = true)
#  |    |    |-- isVideoAd: boolean (nullable = true)
#  |    |    |-- page: string (nullable = true)
#  |    |    |-- slot: string (nullable = true)
#  |    |-- campaign: string (nullable = true)
#  |    |-- campaignCode: string (nullable = true)
#  |    |-- isTrueDirect: boolean (nullable = true)
#  |    |-- keyword: string (nullable = true)
#  |    |-- medium: string (nullable = true)
#  |    |-- referralPath: string (nullable = true)
#  |    |-- source: string (nullable = true)
#  |-- visitId: string (nullable = true)
#  |-- visitNumber: string (nullable = true)
#  |-- visitStartTime: string (nullable = true)

# %% [markdown]
# #### You can explode the entire struct using the * operator

# %% [markdown]
# #### Automating explosion by identifying struct elements in the each column and dtypes to see which require exploding

# %%
dtypes_df = df.withColumn('hits_col_copy', F.col('hits'))\
.withColumn('hits_col_array', F.col('hits_col_copy')[0]).select("hits_col_array.*").dtypes

print(dtypes_df)
# Out:
# [('appInfo', 'struct<exitScreenName:string,landingScreenName:string,screenDepth:string,screenName:string>'), ('contentGroup', 'struct<contentGroup1:string,contentGroup2:string,contentGroup3:string,contentGroup4:string,contentGroup5:string,contentGroupUniqueViews1:string,contentGroupUniqueViews2:string,contentGroupUniqueViews3:string,previousContentGroup1:string,previousContentGroup2:string,previousContentGroup3:string,previousContentGroup4:string,previousContentGroup5:string>'), ('customDimensions', 'array<string>'), ('customMetrics', 'array<string>'), ('customVariables', 'array<string>'), ('dataSource', 'string'), ('eCommerceAction', 'struct<action_type:string,option:string,step:string>'), ('eventInfo', 'struct<eventAction:string,eventCategory:string,eventLabel:string>'), ('exceptionInfo', 'struct<isFatal:boolean>'), ('experiment', 'array<string>'), ('hitNumber', 'string'), ('hour', 'string'), ('isEntrance', 'boolean'), ('isExit', 'boolean'), ('isInteraction', 'boolean'), ('item', 'struct<currencyCode:string,transactionId:string>'), ('latencyTracking', 'struct<domContentLoadedTime:string,domInteractiveTime:string,domLatencyMetricsSample:string,domainLookupTime:string,pageDownloadTime:string,pageLoadSample:string,pageLoadTime:string,redirectionTime:string,serverConnectionTime:string,serverResponseTime:string,speedMetricsSample:string>'), ('minute', 'string'), ('page', 'struct<hostname:string,pagePath:string,pagePathLevel1:string,pagePathLevel2:string,pagePathLevel3:string,pagePathLevel4:string,pageTitle:string,searchCategory:string,searchKeyword:string>'), ('product', 'array<struct<customDimensions:array<string>,customMetrics:array<string>,isClick:boolean,isImpression:boolean,localProductPrice:string,localProductRevenue:string,productBrand:string,productListName:string,productListPosition:string,productPrice:string,productQuantity:string,productRevenue:string,productSKU:string,productVariant:string,v2ProductCategory:string,v2ProductName:string>>'), ('promotion', 'array<struct<promoCreative:string,promoId:string,promoName:string,promoPosition:string>>'), ('promotionActionInfo', 'struct<promoIsClick:boolean,promoIsView:boolean>'), ('publisher_infos', 'array<string>'), ('referer', 'string'), ('social', 'struct<hasSocialSourceReferral:string,socialInteractionNetworkAction:string,socialNetwork:string>'), ('time', 'string'), ('transaction', 'struct<affiliation:string,currencyCode:string,localTransactionRevenue:string,localTransactionShipping:string,localTransactionTax:string,transactionCoupon:string,transactionId:string,transactionRevenue:string,transactionShipping:string,transactionTax:string>'), ('type', 'string')]

# %%
dtypes_df23 = df.withColumn('hits_col_copy', F.col('hits'))\
.withColumn('hits_col_array', F.col('hits_col_copy')[0])\
.withColumn('product',F.col('hits_col_array.product'))\
.withColumn('finalproduct',F.col('product')[0]).select('finalproduct.*').dtypes

# %%
d05 = dtypes_df + dtypes_df23
d05
# Out:
# [('appInfo',
#   'struct<exitScreenName:string,landingScreenName:string,screenDepth:string,screenName:string>'),
#  ('contentGroup',
#   'struct<contentGroup1:string,contentGroup2:string,contentGroup3:string,contentGroup4:string,contentGroup5:string,contentGroupUniqueViews1:string,contentGroupUniqueViews2:string,contentGroupUniqueViews3:string,previousContentGroup1:string,previousContentGroup2:string,previousContentGroup3:string,previousContentGroup4:string,previousContentGroup5:string>'),
#  ('customDimensions', 'array<string>'),
#  ('customMetrics', 'array<string>'),
#  ('customVariables', 'array<string>'),
#  ('dataSource', 'string'),
#  ('eCommerceAction', 'struct<action_type:string,option:string,step:string>'),
#  ('eventInfo',
#   'struct<eventAction:string,eventCategory:string,eventLabel:string>'),
#  ('exceptionInfo', 'struct<isFatal:boolean>'),
#  ('experiment', 'array<string>'),
#  ('hitNumber', 'string'),
#  ('hour', 'string'),
#  ('isEntrance', 'boolean'),
#  ('isExit', 'boolean'),
#  ('isInteraction', 'boolean'),
#  ('item', 'struct<currencyCode:string,transactionId:string>'),
#  ('latencyTracking',
#   'struct<domContentLoadedTime:string,domInteractiveTime:string,domLatencyMetricsSample:string,domainLookupTime:string,pageDownloadTime:string,pageLoadSample:string,pageLoadTime:string,redirectionTime:string,serverConnectionTime:string,serverResponseTime:string,speedMetricsSample:string>'),
#  ('minute', 'string'),
#  ('page',
#   'struct<hostname:string,pagePath:string,pagePathLevel1:string,pagePathLevel2:string,pagePathLevel3:string,pagePathLevel4:string,pageTitle:string,searchCategory:string,searchKeyword:string>'),
#  ('product',
#   'array<struct<customDimensions:array<string>,customMetrics:array<string>,isClick:boolean,isImpression:boolean,localProductPrice:string,localProductRevenue:string,productBrand:string,productListName:string,productListPosition:string,productPrice:string,productQuantity:string,productRevenue:string,productSKU:string,productVariant:string,v2ProductCategory:string,v2ProductName:string>>'),
#  ('promotion',
#   'array<struct<promoCreative:string,promoId:string,promoName:string,promoPosition:string>>'),
#  ('promotionActionInfo', 'struct<promoIsClick:boolean,promoIsView:boolean>'),
#  ('publisher_infos', 'array<string>'),
#  ('referer', 'string'),
#  ('social',
#   'struct<hasSocialSourceReferral:string,socialInteractionNetworkAction:string,socialNetwork:string>'),
#  ('time', 'string'),
#  ('transaction',
#   'struct<affiliation:string,currencyCode:string,localTransactionRevenue:string,localTransactionShipping:string,localTransactionTax:string,transactionCoupon:string,transactionId:string,transactionRevenue:string,transactionShipping:string,transactionTax:string>'),
#  ('type', 'string'),
#  ('customDimensions', 'array<string>'),
#  ('customMetrics', 'array<string>'),
#  ('isClick', 'boolean'),
#  ('isImpression', 'boolean'),
#  ('localProductPrice', 'string'),
#  ('localProductRevenue', 'string'),
#  ('productBrand', 'string'),
#  ('productListName', 'string'),
#  ('productListPosition', 'string'),
#  ('productPrice', 'string'),
#  ('productQuantity', 'string'),
#  ('productRevenue', 'string'),
#  ('productSKU', 'string'),
#  ('productVariant', 'string'),
#  ('v2ProductCategory', 'string'),
#  ('v2ProductName', 'string')]

# %%
dtypes_df1 = df.withColumn('device_col_array',F.col('device')).select("device_col_array.*").dtypes
print(dtypes_df1)
# Out:
# [('browser', 'string'), ('browserSize', 'string'), ('browserVersion', 'string'), ('deviceCategory', 'string'), ('flashVersion', 'string'), ('isMobile', 'boolean'), ('language', 'string'), ('mobileDeviceBranding', 'string'), ('mobileDeviceInfo', 'string'), ('mobileDeviceMarketingName', 'string'), ('mobileDeviceModel', 'string'), ('mobileInputSelector', 'string'), ('operatingSystem', 'string'), ('operatingSystemVersion', 'string'), ('screenColors', 'string'), ('screenResolution', 'string')]

# %%
dtypes_df2 = df.withColumn('customDimensions_col_array', F.col('customDimensions')[0]).select("customDimensions_col_array.*").dtypes
  
print(dtypes_df2)
# Out:
# [('index', 'string'), ('value', 'string')]

# %%
dtypes_df3 = df.withColumn('geoNetwork_col_array', F.col('geoNetwork')).select("geoNetwork_col_array.*").dtypes

print(dtypes_df3)
# Out:
# [('city', 'string'), ('cityId', 'string'), ('continent', 'string'), ('country', 'string'), ('latitude', 'string'), ('longitude', 'string'), ('metro', 'string'), ('networkDomain', 'string'), ('networkLocation', 'string'), ('region', 'string'), ('subContinent', 'string')]

# %%
dtypes_df4 = df.withColumn('totals_col_array', F.col('totals')).select("totals_col_array.*").dtypes

print(dtypes_df4)
# Out:
# [('bounces', 'string'), ('hits', 'string'), ('newVisits', 'string'), ('pageviews', 'string'), ('sessionQualityDim', 'string'), ('timeOnSite', 'string'), ('totalTransactionRevenue', 'string'), ('transactionRevenue', 'string'), ('transactions', 'string'), ('visits', 'string')]

# %%
dtypes_df5 = df.withColumn('trafficSource_col_array', F.col('trafficSource')).select("trafficSource_col_array.*").dtypes
print(dtypes_df5)
# Out:
# [('adContent', 'string'), ('adwordsClickInfo', 'struct<adNetworkType:string,criteriaParameters:string,gclId:string,isVideoAd:boolean,page:string,slot:string>'), ('campaign', 'string'), ('campaignCode', 'string'), ('isTrueDirect', 'boolean'), ('keyword', 'string'), ('medium', 'string'), ('referralPath', 'string'), ('source', 'string')]

# %%
struct_items05 = [item[0] for item in d05 if item[1].startswith('struct')]
print(struct_items05)
# Out:
# ['appInfo', 'contentGroup', 'eCommerceAction', 'eventInfo', 'exceptionInfo', 'item', 'latencyTracking', 'page', 'promotionActionInfo', 'social', 'transaction']

# %% [markdown]
# **Identify a column key including exlpode struct, we will use this key as an identifier to select all columns **

# %%
explode_struct_cols = ["hits_col_array." +col + ".*" for col in struct_items05]
explode_struct_cols
# Out:
# ['hits_col_array.appInfo.*',
#  'hits_col_array.contentGroup.*',
#  'hits_col_array.eCommerceAction.*',
#  'hits_col_array.eventInfo.*',
#  'hits_col_array.exceptionInfo.*',
#  'hits_col_array.item.*',
#  'hits_col_array.latencyTracking.*',
#  'hits_col_array.page.*',
#  'hits_col_array.promotionActionInfo.*',
#  'hits_col_array.social.*',
#  'hits_col_array.transaction.*']

# %%
explode_list = [i+'.*' for i in df.columns]
print(explode_list)
# Out:
# ['channelGrouping.*', 'customDimensions.*', 'date.*', 'device.*', 'fullVisitorId.*', 'geoNetwork.*', 'hits.*', 'socialEngagementType.*', 'totals.*', 'trafficSource.*', 'visitId.*', 'visitNumber.*', 'visitStartTime.*']

# %%
exp_list = ['channelGrouping','customDimensions.value','date', 'device.*', 'fullVisitorId', 'geoNetwork.*', 'socialEngagementType', 'totals.*', 'trafficSource.*', 'visitId', 'visitNumber', 'visitStartTime','product.*']

# %%
col_names = exp_list + explode_struct_cols
print(col_names)
# Out:
# ['channelGrouping', 'customDimensions.value', 'date', 'device.*', 'fullVisitorId', 'geoNetwork.*', 'socialEngagementType', 'totals.*', 'trafficSource.*', 'visitId', 'visitNumber', 'visitStartTime', 'product.*', 'hits_col_array.appInfo.*', 'hits_col_array.contentGroup.*', 'hits_col_array.eCommerceAction.*', 'hits_col_array.eventInfo.*', 'hits_col_array.exceptionInfo.*', 'hits_col_array.item.*', 'hits_col_array.latencyTracking.*', 'hits_col_array.page.*', 'hits_col_array.promotionActionInfo.*', 'hits_col_array.social.*', 'hits_col_array.transaction.*']

# %% [markdown]
# **Subset a new dataframe with all the columns from original set are exploded into each indivdual columns**

# %%
flatdf = df.withColumn('hits_col_copy', F.col('hits'))\
        .withColumn('hits_col_array', F.col('hits_col_copy')[0])\
        .withColumn('product',F.col('hits_col_array.product'))\
        .withColumn('product',F.col('product')[0])\
        .select(col_names)

# %%
flatdf.show(n=10,truncate = False)
# Out:
# +---------------+---------------+--------+-------+-----------------------------+-----------------------------+--------------+-----------------------------+--------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------+-----------------------------+-----------------------------+-----------------------------+-------------------+-----------+-----------------------------+---------+--------------+-----------------------------+-----------------------------+---------------------------------+-----------------+-----------------------------+-----------------+----------------+--------------------+-------+----+---------+---------+-----------------+----------+-----------------------+------------------+------------+------+---------+-------------------------------------------------------------+---------+------------+------------+--------------+-------+------------+--------+----------+-----------+--------------+----------------+-------------+-------+------------+-----------------+-------------------+------------+---------------+-------------------+------------+---------------+--------------+------------+--------------+----------------------------------+----------------------------------------------------+--------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------+-----------+--------------------------------------------------------------------------+-------------+-------------+-------------+-------------+-------------+------------------------+------------------------+------------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-----------+------+----+-----------+-------------+----------+-------+------------+-------------+--------------------+------------------+-----------------------+----------------+----------------+--------------+------------+---------------+--------------------+------------------+------------------+-------------------------------+-------------------------------------------+-----------------+--------------+--------------+--------------+---------------------------------------------------+--------------+-------------+------------+-----------+-----------------------+------------------------------+-------------+-----------+------------+-----------------------+------------------------+-------------------+-----------------+-------------+------------------+-------------------+--------------+
# |channelGrouping|value          |date    |browser|browserSize                  |browserVersion               |deviceCategory|flashVersion                 |isMobile|language                     |mobileDeviceBranding         |mobileDeviceInfo             |mobileDeviceMarketingName    |mobileDeviceModel            |mobileInputSelector          |operatingSystem|operatingSystemVersion       |screenColors                 |screenResolution             |fullVisitorId      |city       |cityId                       |continent|country       |latitude                     |longitude                    |metro                            |networkDomain    |networkLocation              |region           |subContinent    |socialEngagementType|bounces|hits|newVisits|pageviews|sessionQualityDim|timeOnSite|totalTransactionRevenue|transactionRevenue|transactions|visits|adContent|adwordsClickInfo                                             |campaign |campaignCode|isTrueDirect|keyword       |medium |referralPath|source  |visitId   |visitNumber|visitStartTime|customDimensions|customMetrics|isClick|isImpression|localProductPrice|localProductRevenue|productBrand|productListName|productListPosition|productPrice|productQuantity|productRevenue|productSKU  |productVariant|v2ProductCategory                 |v2ProductName                                       |exitScreenName                                                                                    |landingScreenName                                                         |screenDepth|screenName                                                                |contentGroup1|contentGroup2|contentGroup3|contentGroup4|contentGroup5|contentGroupUniqueViews1|contentGroupUniqueViews2|contentGroupUniqueViews3|previousContentGroup1|previousContentGroup2|previousContentGroup3|previousContentGroup4|previousContentGroup5|action_type|option|step|eventAction|eventCategory|eventLabel|isFatal|currencyCode|transactionId|domContentLoadedTime|domInteractiveTime|domLatencyMetricsSample|domainLookupTime|pageDownloadTime|pageLoadSample|pageLoadTime|redirectionTime|serverConnectionTime|serverResponseTime|speedMetricsSample|hostname                       |pagePath                                   |pagePathLevel1   |pagePathLevel2|pagePathLevel3|pagePathLevel4|pageTitle                                          |searchCategory|searchKeyword|promoIsClick|promoIsView|hasSocialSourceReferral|socialInteractionNetworkAction|socialNetwork|affiliation|currencyCode|localTransactionRevenue|localTransactionShipping|localTransactionTax|transactionCoupon|transactionId|transactionRevenue|transactionShipping|transactionTax|
# +---------------+---------------+--------+-------+-----------------------------+-----------------------------+--------------+-----------------------------+--------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------+-----------------------------+-----------------------------+-----------------------------+-------------------+-----------+-----------------------------+---------+--------------+-----------------------------+-----------------------------+---------------------------------+-----------------+-----------------------------+-----------------+----------------+--------------------+-------+----+---------+---------+-----------------+----------+-----------------------+------------------+------------+------+---------+-------------------------------------------------------------+---------+------------+------------+--------------+-------+------------+--------+----------+-----------+--------------+----------------+-------------+-------+------------+-----------------+-------------------+------------+---------------+-------------------+------------+---------------+--------------+------------+--------------+----------------------------------+----------------------------------------------------+--------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------+-----------+--------------------------------------------------------------------------+-------------+-------------+-------------+-------------+-------------+------------------------+------------------------+------------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-----------+------+----+-----------+-------------+----------+-------+------------+-------------+--------------------+------------------+-----------------------+----------------+----------------+--------------+------------+---------------+--------------------+------------------+------------------+-------------------------------+-------------------------------------------+-----------------+--------------+--------------+--------------+---------------------------------------------------+--------------+-------------+------------+-----------+-----------------------+------------------------------+-------------+-----------+------------+-----------------------+------------------------+-------------------+-----------------+-------------+------------------+-------------------+--------------+
# |Referral       |[North America]|20170531|Chrome |not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Linux          |not available in demo dataset|not available in demo dataset|not available in demo dataset|5988717949752143819|New York   |not available in demo dataset|Americas |United States |not available in demo dataset|not available in demo dataset|New York NY                      |(not set)        |not available in demo dataset|New York         |Northern America|Not Socially Engaged|null   |5   |null     |5        |null             |22        |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |true        |null          |(none) |/           |(direct)|1496250487|3          |1496250487    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |shop.googlemerchandisestore.com/store.html                                                        |shop.googlemerchandisestore.com/home                                      |0          |shop.googlemerchandisestore.com/home                                      |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |shop.googlemerchandisestore.com|/home                                      |/home            |              |              |              |Home                                               |null          |null         |null        |true       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Referral       |[]             |20170531|Chrome |not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Macintosh      |not available in demo dataset|not available in demo dataset|not available in demo dataset|1914206347497291855|(not set)  |not available in demo dataset|Asia     |Hong Kong     |not available in demo dataset|not available in demo dataset|(not set)                        |netvigator.com   |not available in demo dataset|(not set)        |Eastern Asia    |Not Socially Engaged|null   |7   |null     |7        |null             |348       |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |true        |null          |(none) |/           |(direct)|1496242570|7          |1496242570    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |shop.googlemerchandisestore.com/google+redesign/office                                            |shop.googlemerchandisestore.com/home                                      |0          |shop.googlemerchandisestore.com/home                                      |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |shop.googlemerchandisestore.com|/home                                      |/home            |              |              |              |Home                                               |null          |null         |null        |true       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Referral       |[North America]|20170531|Chrome |not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Macintosh      |not available in demo dataset|not available in demo dataset|not available in demo dataset|5688612779726117211|New York   |not available in demo dataset|Americas |United States |not available in demo dataset|not available in demo dataset|New York NY                      |(not set)        |not available in demo dataset|New York         |Northern America|Not Socially Engaged|null   |8   |null     |8        |null             |207       |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |null        |null          |(none) |/           |(direct)|1496268814|2          |1496268814    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |shop.googlemerchandisestore.com/google+redesign/apparel/women+s+google+lightweight+microfleece.axd|shop.googlemerchandisestore.com/home                                      |0          |shop.googlemerchandisestore.com/home                                      |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |shop.googlemerchandisestore.com|/home                                      |/home            |              |              |              |Home                                               |null          |null         |null        |true       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Direct         |[South America]|20170531|Chrome |not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Windows        |not available in demo dataset|not available in demo dataset|not available in demo dataset|5995173173416756249|Santa Fe   |not available in demo dataset|Americas |Argentina     |not available in demo dataset|not available in demo dataset|(not set)                        |fibertel.com.ar  |not available in demo dataset|Santa Fe Province|South America   |Not Socially Engaged|null   |10  |null     |10       |null             |248       |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |true        |null          |(none) |null        |(direct)|1496260952|2          |1496260952    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |shop.googlemerchandisestore.com/google+redesign/office/writing+instruments                        |shop.googlemerchandisestore.com/home                                      |0          |shop.googlemerchandisestore.com/home                                      |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |shop.googlemerchandisestore.com|/home                                      |/home            |              |              |              |Home                                               |null          |null         |null        |true       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Referral       |[North America]|20170531|Chrome |not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Macintosh      |not available in demo dataset|not available in demo dataset|not available in demo dataset|5703962423814396269|Los Angeles|not available in demo dataset|Americas |United States |not available in demo dataset|not available in demo dataset|Los Angeles CA                   |(not set)        |not available in demo dataset|California       |Northern America|Not Socially Engaged|null   |39  |null     |25       |null             |2040      |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |true        |null          |(none) |/           |(direct)|1496262254|22         |1496262254    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |shop.googlemerchandisestore.com/basket.html                                                       |shop.googlemerchandisestore.com/home                                      |0          |shop.googlemerchandisestore.com/home                                      |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |shop.googlemerchandisestore.com|/home                                      |/home            |              |              |              |Home                                               |null          |null         |null        |true       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Organic Search |[North America]|20170531|Firefox|not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Macintosh      |not available in demo dataset|not available in demo dataset|not available in demo dataset|1192333145578267748|Toronto    |not available in demo dataset|Americas |Canada        |not available in demo dataset|not available in demo dataset|(not set)                        |primus.ca        |not available in demo dataset|Ontario          |Northern America|Not Socially Engaged|null   |80  |null     |64       |null             |4726      |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |true        |(not provided)|organic|null        |google  |1496280352|2          |1496280352    |[]              |[]           |null   |true        |16990000         |null               |(not set)   |Category       |1                  |16990000    |null           |null          |GGOEGAAX0104|(not set)     |Home/Apparel/Men's/Men's-T-Shirts/|Google Men's 100% Cotton Short Sleeve Hero Tee White|shop.googlemerchandisestore.com/basket.html                                                       |shop.googlemerchandisestore.com/google+redesign/apparel/mens/mens+t+shirts|0          |shop.googlemerchandisestore.com/google+redesign/apparel/mens/mens+t+shirts|(not set)    |Apparel      |(not set)    |(not set)    |(not set)    |null                    |1                       |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |USD         |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |shop.googlemerchandisestore.com|/google+redesign/apparel/mens/mens+t+shirts|/google+redesign/|/apparel/     |/mens/        |/mens+t+shirts|Men's T-Shirts | Apparel | Google Merchandise Store|null          |null         |null        |null       |No                     | :                            |(not set)    |null       |USD         |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Direct         |[North America]|20170531|Safari |not available in demo dataset|not available in demo dataset|mobile        |not available in demo dataset|true    |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|iOS            |not available in demo dataset|not available in demo dataset|not available in demo dataset|0423250391712266292|Sunnyvale  |not available in demo dataset|Americas |United States |not available in demo dataset|not available in demo dataset|San Francisco-Oakland-San Jose CA|americanfarms.net|not available in demo dataset|California       |Northern America|Not Socially Engaged|1      |1   |null     |1        |null             |null      |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |true        |null          |(none) |null        |(direct)|1496242282|2          |1496242282    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |www.googlemerchandisestore.com/home                                                               |www.googlemerchandisestore.com/home                                       |0          |www.googlemerchandisestore.com/home                                       |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |www.googlemerchandisestore.com |/home                                      |/home            |              |              |              |Google Online Store                                |null          |null         |null        |null       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Organic Search |[EMEA]         |20170531|Chrome |not available in demo dataset|not available in demo dataset|mobile        |not available in demo dataset|true    |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Android        |not available in demo dataset|not available in demo dataset|not available in demo dataset|5476517208251322333|London     |not available in demo dataset|Europe   |United Kingdom|not available in demo dataset|not available in demo dataset|London                           |(not set)        |not available in demo dataset|England          |Northern Europe |Not Socially Engaged|1      |1   |1        |1        |null             |null      |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |null        |(not provided)|organic|null        |google  |1496242202|1          |1496242202    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |www.googlemerchandisestore.com/home                                                               |www.googlemerchandisestore.com/home                                       |0          |www.googlemerchandisestore.com/home                                       |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |www.googlemerchandisestore.com |/home                                      |/home            |              |              |              |Google Online Store                                |null          |null         |null        |null       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Organic Search |[EMEA]         |20170531|Chrome |not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Windows        |not available in demo dataset|not available in demo dataset|not available in demo dataset|7457135857298103204|(not set)  |not available in demo dataset|Europe   |Netherlands   |not available in demo dataset|not available in demo dataset|(not set)                        |hp.net           |not available in demo dataset|(not set)        |Western Europe  |Not Socially Engaged|1      |1   |1        |1        |null             |null      |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |null        |(not provided)|organic|null        |google  |1496227837|1          |1496227837    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |www.googlemerchandisestore.com/home                                                               |www.googlemerchandisestore.com/home                                       |0          |www.googlemerchandisestore.com/home                                       |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |www.googlemerchandisestore.com |/home                                      |/home            |              |              |              |Google Online Store                                |null          |null         |null        |null       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Organic Search |[EMEA]         |20170531|Firefox|not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Macintosh      |not available in demo dataset|not available in demo dataset|not available in demo dataset|4500406506454646175|Berlin     |not available in demo dataset|Europe   |Germany       |not available in demo dataset|not available in demo dataset|(not set)                        |t-ipconnect.de   |not available in demo dataset|Berlin           |Western Europe  |Not Socially Engaged|1      |1   |null     |1        |null             |null      |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |true        |(not provided)|organic|null        |google  |1496240339|7          |1496240339    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |www.googlemerchandisestore.com/home                                                               |www.googlemerchandisestore.com/home                                       |0          |www.googlemerchandisestore.com/home                                       |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |www.googlemerchandisestore.com |/home                                      |/home            |              |              |              |Google Online Store                                |null          |null         |null        |null       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# +---------------+---------------+--------+-------+-----------------------------+-----------------------------+--------------+-----------------------------+--------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------+-----------------------------+-----------------------------+-----------------------------+-------------------+-----------+-----------------------------+---------+--------------+-----------------------------+-----------------------------+---------------------------------+-----------------+-----------------------------+-----------------+----------------+--------------------+-------+----+---------+---------+-----------------+----------+-----------------------+------------------+------------+------+---------+-------------------------------------------------------------+---------+------------+------------+--------------+-------+------------+--------+----------+-----------+--------------+----------------+-------------+-------+------------+-----------------+-------------------+------------+---------------+-------------------+------------+---------------+--------------+------------+--------------+----------------------------------+----------------------------------------------------+--------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------+-----------+--------------------------------------------------------------------------+-------------+-------------+-------------+-------------+-------------+------------------------+------------------------+------------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-----------+------+----+-----------+-------------+----------+-------+------------+-------------+--------------------+------------------+-----------------------+----------------+----------------+--------------+------------+---------------+--------------------+------------------+------------------+-------------------------------+-------------------------------------------+-----------------+--------------+--------------+--------------+---------------------------------------------------+--------------+-------------+------------+-----------+-----------------------+------------------------------+-------------+-----------+------------+-----------------------+------------------------+-------------------+-----------------+-------------+------------------+-------------------+--------------+
# only showing top 10 rows

# %% [markdown]
# ### **2.2: Data Cleaning**: Now that we have all our data in individual columns, we are going to tidy up and reduce the memory size to make it easire for reading and storage.

# %%
flatdf.dtypes
# Out:
# [('channelGrouping', 'string'),
#  ('value', 'array<string>'),
#  ('date', 'string'),
#  ('browser', 'string'),
#  ('browserSize', 'string'),
#  ('browserVersion', 'string'),
#  ('deviceCategory', 'string'),
#  ('flashVersion', 'string'),
#  ('isMobile', 'boolean'),
#  ('language', 'string'),
#  ('mobileDeviceBranding', 'string'),
#  ('mobileDeviceInfo', 'string'),
#  ('mobileDeviceMarketingName', 'string'),
#  ('mobileDeviceModel', 'string'),
#  ('mobileInputSelector', 'string'),
#  ('operatingSystem', 'string'),
#  ('operatingSystemVersion', 'string'),
#  ('screenColors', 'string'),
#  ('screenResolution', 'string'),
#  ('fullVisitorId', 'string'),
#  ('city', 'string'),
#  ('cityId', 'string'),
#  ('continent', 'string'),
#  ('country', 'string'),
#  ('latitude', 'string'),
#  ('longitude', 'string'),
#  ('metro', 'string'),
#  ('networkDomain', 'string'),
#  ('networkLocation', 'string'),
#  ('region', 'string'),
#  ('subContinent', 'string'),
#  ('socialEngagementType', 'string'),
#  ('bounces', 'string'),
#  ('hits', 'string'),
#  ('newVisits', 'string'),
#  ('pageviews', 'string'),
#  ('sessionQualityDim', 'string'),
#  ('timeOnSite', 'string'),
#  ('totalTransactionRevenue', 'string'),
#  ('transactionRevenue', 'string'),
#  ('transactions', 'string'),
#  ('visits', 'string'),
#  ('adContent', 'string'),
#  ('adwordsClickInfo',
#   'struct<adNetworkType:string,criteriaParameters:string,gclId:string,isVideoAd:boolean,page:string,slot:string>'),
#  ('campaign', 'string'),
#  ('campaignCode', 'string'),
#  ('isTrueDirect', 'boolean'),
#  ('keyword', 'string'),
#  ('medium', 'string'),
#  ('referralPath', 'string'),
#  ('source', 'string'),
#  ('visitId', 'string'),
#  ('visitNumber', 'string'),
#  ('visitStartTime', 'string'),
#  ('customDimensions', 'array<string>'),
#  ('customMetrics', 'array<string>'),
#  ('isClick', 'boolean'),
#  ('isImpression', 'boolean'),
#  ('localProductPrice', 'string'),
#  ('localProductRevenue', 'string'),
#  ('productBrand', 'string'),
#  ('productListName', 'string'),
#  ('productListPosition', 'string'),
#  ('productPrice', 'string'),
#  ('productQuantity', 'string'),
#  ('productRevenue', 'string'),
#  ('productSKU', 'string'),
#  ('productVariant', 'string'),
#  ('v2ProductCategory', 'string'),
#  ('v2ProductName', 'string'),
#  ('exitScreenName', 'string'),
#  ('landingScreenName', 'string'),
#  ('screenDepth', 'string'),
#  ('screenName', 'string'),
#  ('contentGroup1', 'string'),
#  ('contentGroup2', 'string'),
#  ('contentGroup3', 'string'),
#  ('contentGroup4', 'string'),
#  ('contentGroup5', 'string'),
#  ('contentGroupUniqueViews1', 'string'),
#  ('contentGroupUniqueViews2', 'string'),
#  ('contentGroupUniqueViews3', 'string'),
#  ('previousContentGroup1', 'string'),
#  ('previousContentGroup2', 'string'),
#  ('previousContentGroup3', 'string'),
#  ('previousContentGroup4', 'string'),
#  ('previousContentGroup5', 'string'),
#  ('action_type', 'string'),
#  ('option', 'string'),
#  ('step', 'string'),
#  ('eventAction', 'string'),
#  ('eventCategory', 'string'),
#  ('eventLabel', 'string'),
#  ('isFatal', 'boolean'),
#  ('currencyCode', 'string'),
#  ('transactionId', 'string'),
#  ('domContentLoadedTime', 'string'),
#  ('domInteractiveTime', 'string'),
#  ('domLatencyMetricsSample', 'string'),
#  ('domainLookupTime', 'string'),
#  ('pageDownloadTime', 'string'),
#  ('pageLoadSample', 'string'),
#  ('pageLoadTime', 'string'),
#  ('redirectionTime', 'string'),
#  ('serverConnectionTime', 'string'),
#  ('serverResponseTime', 'string'),
#  ('speedMetricsSample', 'string'),
#  ('hostname', 'string'),
#  ('pagePath', 'string'),
#  ('pagePathLevel1', 'string'),
#  ('pagePathLevel2', 'string'),
#  ('pagePathLevel3', 'string'),
#  ('pagePathLevel4', 'string'),
#  ('pageTitle', 'string'),
#  ('searchCategory', 'string'),
#  ('searchKeyword', 'string'),
#  ('promoIsClick', 'boolean'),
#  ('promoIsView', 'boolean'),
#  ('hasSocialSourceReferral', 'string'),
#  ('socialInteractionNetworkAction', 'string'),
#  ('socialNetwork', 'string'),
#  ('affiliation', 'string'),
#  ('currencyCode', 'string'),
#  ('localTransactionRevenue', 'string'),
#  ('localTransactionShipping', 'string'),
#  ('localTransactionTax', 'string'),
#  ('transactionCoupon', 'string'),
#  ('transactionId', 'string'),
#  ('transactionRevenue', 'string'),
#  ('transactionShipping', 'string'),
#  ('transactionTax', 'string')]

# %% [markdown]
# 2.2.1 Drop columns we are not going to use.

# %%
flatdf.show(n=10,truncate=False)
# Out:
# +---------------+---------------+--------+-------+-----------------------------+-----------------------------+--------------+-----------------------------+--------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------+-----------------------------+-----------------------------+-----------------------------+-------------------+-----------+-----------------------------+---------+--------------+-----------------------------+-----------------------------+---------------------------------+-----------------+-----------------------------+-----------------+----------------+--------------------+-------+----+---------+---------+-----------------+----------+-----------------------+------------------+------------+------+---------+-------------------------------------------------------------+---------+------------+------------+--------------+-------+------------+--------+----------+-----------+--------------+----------------+-------------+-------+------------+-----------------+-------------------+------------+---------------+-------------------+------------+---------------+--------------+------------+--------------+----------------------------------+----------------------------------------------------+--------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------+-----------+--------------------------------------------------------------------------+-------------+-------------+-------------+-------------+-------------+------------------------+------------------------+------------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-----------+------+----+-----------+-------------+----------+-------+------------+-------------+--------------------+------------------+-----------------------+----------------+----------------+--------------+------------+---------------+--------------------+------------------+------------------+-------------------------------+-------------------------------------------+-----------------+--------------+--------------+--------------+---------------------------------------------------+--------------+-------------+------------+-----------+-----------------------+------------------------------+-------------+-----------+------------+-----------------------+------------------------+-------------------+-----------------+-------------+------------------+-------------------+--------------+
# |channelGrouping|value          |date    |browser|browserSize                  |browserVersion               |deviceCategory|flashVersion                 |isMobile|language                     |mobileDeviceBranding         |mobileDeviceInfo             |mobileDeviceMarketingName    |mobileDeviceModel            |mobileInputSelector          |operatingSystem|operatingSystemVersion       |screenColors                 |screenResolution             |fullVisitorId      |city       |cityId                       |continent|country       |latitude                     |longitude                    |metro                            |networkDomain    |networkLocation              |region           |subContinent    |socialEngagementType|bounces|hits|newVisits|pageviews|sessionQualityDim|timeOnSite|totalTransactionRevenue|transactionRevenue|transactions|visits|adContent|adwordsClickInfo                                             |campaign |campaignCode|isTrueDirect|keyword       |medium |referralPath|source  |visitId   |visitNumber|visitStartTime|customDimensions|customMetrics|isClick|isImpression|localProductPrice|localProductRevenue|productBrand|productListName|productListPosition|productPrice|productQuantity|productRevenue|productSKU  |productVariant|v2ProductCategory                 |v2ProductName                                       |exitScreenName                                                                                    |landingScreenName                                                         |screenDepth|screenName                                                                |contentGroup1|contentGroup2|contentGroup3|contentGroup4|contentGroup5|contentGroupUniqueViews1|contentGroupUniqueViews2|contentGroupUniqueViews3|previousContentGroup1|previousContentGroup2|previousContentGroup3|previousContentGroup4|previousContentGroup5|action_type|option|step|eventAction|eventCategory|eventLabel|isFatal|currencyCode|transactionId|domContentLoadedTime|domInteractiveTime|domLatencyMetricsSample|domainLookupTime|pageDownloadTime|pageLoadSample|pageLoadTime|redirectionTime|serverConnectionTime|serverResponseTime|speedMetricsSample|hostname                       |pagePath                                   |pagePathLevel1   |pagePathLevel2|pagePathLevel3|pagePathLevel4|pageTitle                                          |searchCategory|searchKeyword|promoIsClick|promoIsView|hasSocialSourceReferral|socialInteractionNetworkAction|socialNetwork|affiliation|currencyCode|localTransactionRevenue|localTransactionShipping|localTransactionTax|transactionCoupon|transactionId|transactionRevenue|transactionShipping|transactionTax|
# +---------------+---------------+--------+-------+-----------------------------+-----------------------------+--------------+-----------------------------+--------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------+-----------------------------+-----------------------------+-----------------------------+-------------------+-----------+-----------------------------+---------+--------------+-----------------------------+-----------------------------+---------------------------------+-----------------+-----------------------------+-----------------+----------------+--------------------+-------+----+---------+---------+-----------------+----------+-----------------------+------------------+------------+------+---------+-------------------------------------------------------------+---------+------------+------------+--------------+-------+------------+--------+----------+-----------+--------------+----------------+-------------+-------+------------+-----------------+-------------------+------------+---------------+-------------------+------------+---------------+--------------+------------+--------------+----------------------------------+----------------------------------------------------+--------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------+-----------+--------------------------------------------------------------------------+-------------+-------------+-------------+-------------+-------------+------------------------+------------------------+------------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-----------+------+----+-----------+-------------+----------+-------+------------+-------------+--------------------+------------------+-----------------------+----------------+----------------+--------------+------------+---------------+--------------------+------------------+------------------+-------------------------------+-------------------------------------------+-----------------+--------------+--------------+--------------+---------------------------------------------------+--------------+-------------+------------+-----------+-----------------------+------------------------------+-------------+-----------+------------+-----------------------+------------------------+-------------------+-----------------+-------------+------------------+-------------------+--------------+
# |Referral       |[North America]|20170531|Chrome |not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Linux          |not available in demo dataset|not available in demo dataset|not available in demo dataset|5988717949752143819|New York   |not available in demo dataset|Americas |United States |not available in demo dataset|not available in demo dataset|New York NY                      |(not set)        |not available in demo dataset|New York         |Northern America|Not Socially Engaged|null   |5   |null     |5        |null             |22        |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |true        |null          |(none) |/           |(direct)|1496250487|3          |1496250487    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |shop.googlemerchandisestore.com/store.html                                                        |shop.googlemerchandisestore.com/home                                      |0          |shop.googlemerchandisestore.com/home                                      |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |shop.googlemerchandisestore.com|/home                                      |/home            |              |              |              |Home                                               |null          |null         |null        |true       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Referral       |[]             |20170531|Chrome |not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Macintosh      |not available in demo dataset|not available in demo dataset|not available in demo dataset|1914206347497291855|(not set)  |not available in demo dataset|Asia     |Hong Kong     |not available in demo dataset|not available in demo dataset|(not set)                        |netvigator.com   |not available in demo dataset|(not set)        |Eastern Asia    |Not Socially Engaged|null   |7   |null     |7        |null             |348       |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |true        |null          |(none) |/           |(direct)|1496242570|7          |1496242570    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |shop.googlemerchandisestore.com/google+redesign/office                                            |shop.googlemerchandisestore.com/home                                      |0          |shop.googlemerchandisestore.com/home                                      |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |shop.googlemerchandisestore.com|/home                                      |/home            |              |              |              |Home                                               |null          |null         |null        |true       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Referral       |[North America]|20170531|Chrome |not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Macintosh      |not available in demo dataset|not available in demo dataset|not available in demo dataset|5688612779726117211|New York   |not available in demo dataset|Americas |United States |not available in demo dataset|not available in demo dataset|New York NY                      |(not set)        |not available in demo dataset|New York         |Northern America|Not Socially Engaged|null   |8   |null     |8        |null             |207       |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |null        |null          |(none) |/           |(direct)|1496268814|2          |1496268814    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |shop.googlemerchandisestore.com/google+redesign/apparel/women+s+google+lightweight+microfleece.axd|shop.googlemerchandisestore.com/home                                      |0          |shop.googlemerchandisestore.com/home                                      |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |shop.googlemerchandisestore.com|/home                                      |/home            |              |              |              |Home                                               |null          |null         |null        |true       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Direct         |[South America]|20170531|Chrome |not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Windows        |not available in demo dataset|not available in demo dataset|not available in demo dataset|5995173173416756249|Santa Fe   |not available in demo dataset|Americas |Argentina     |not available in demo dataset|not available in demo dataset|(not set)                        |fibertel.com.ar  |not available in demo dataset|Santa Fe Province|South America   |Not Socially Engaged|null   |10  |null     |10       |null             |248       |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |true        |null          |(none) |null        |(direct)|1496260952|2          |1496260952    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |shop.googlemerchandisestore.com/google+redesign/office/writing+instruments                        |shop.googlemerchandisestore.com/home                                      |0          |shop.googlemerchandisestore.com/home                                      |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |shop.googlemerchandisestore.com|/home                                      |/home            |              |              |              |Home                                               |null          |null         |null        |true       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Referral       |[North America]|20170531|Chrome |not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Macintosh      |not available in demo dataset|not available in demo dataset|not available in demo dataset|5703962423814396269|Los Angeles|not available in demo dataset|Americas |United States |not available in demo dataset|not available in demo dataset|Los Angeles CA                   |(not set)        |not available in demo dataset|California       |Northern America|Not Socially Engaged|null   |39  |null     |25       |null             |2040      |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |true        |null          |(none) |/           |(direct)|1496262254|22         |1496262254    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |shop.googlemerchandisestore.com/basket.html                                                       |shop.googlemerchandisestore.com/home                                      |0          |shop.googlemerchandisestore.com/home                                      |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |shop.googlemerchandisestore.com|/home                                      |/home            |              |              |              |Home                                               |null          |null         |null        |true       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Organic Search |[North America]|20170531|Firefox|not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Macintosh      |not available in demo dataset|not available in demo dataset|not available in demo dataset|1192333145578267748|Toronto    |not available in demo dataset|Americas |Canada        |not available in demo dataset|not available in demo dataset|(not set)                        |primus.ca        |not available in demo dataset|Ontario          |Northern America|Not Socially Engaged|null   |80  |null     |64       |null             |4726      |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |true        |(not provided)|organic|null        |google  |1496280352|2          |1496280352    |[]              |[]           |null   |true        |16990000         |null               |(not set)   |Category       |1                  |16990000    |null           |null          |GGOEGAAX0104|(not set)     |Home/Apparel/Men's/Men's-T-Shirts/|Google Men's 100% Cotton Short Sleeve Hero Tee White|shop.googlemerchandisestore.com/basket.html                                                       |shop.googlemerchandisestore.com/google+redesign/apparel/mens/mens+t+shirts|0          |shop.googlemerchandisestore.com/google+redesign/apparel/mens/mens+t+shirts|(not set)    |Apparel      |(not set)    |(not set)    |(not set)    |null                    |1                       |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |USD         |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |shop.googlemerchandisestore.com|/google+redesign/apparel/mens/mens+t+shirts|/google+redesign/|/apparel/     |/mens/        |/mens+t+shirts|Men's T-Shirts | Apparel | Google Merchandise Store|null          |null         |null        |null       |No                     | :                            |(not set)    |null       |USD         |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Direct         |[North America]|20170531|Safari |not available in demo dataset|not available in demo dataset|mobile        |not available in demo dataset|true    |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|iOS            |not available in demo dataset|not available in demo dataset|not available in demo dataset|0423250391712266292|Sunnyvale  |not available in demo dataset|Americas |United States |not available in demo dataset|not available in demo dataset|San Francisco-Oakland-San Jose CA|americanfarms.net|not available in demo dataset|California       |Northern America|Not Socially Engaged|1      |1   |null     |1        |null             |null      |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |true        |null          |(none) |null        |(direct)|1496242282|2          |1496242282    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |www.googlemerchandisestore.com/home                                                               |www.googlemerchandisestore.com/home                                       |0          |www.googlemerchandisestore.com/home                                       |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |www.googlemerchandisestore.com |/home                                      |/home            |              |              |              |Google Online Store                                |null          |null         |null        |null       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Organic Search |[EMEA]         |20170531|Chrome |not available in demo dataset|not available in demo dataset|mobile        |not available in demo dataset|true    |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Android        |not available in demo dataset|not available in demo dataset|not available in demo dataset|5476517208251322333|London     |not available in demo dataset|Europe   |United Kingdom|not available in demo dataset|not available in demo dataset|London                           |(not set)        |not available in demo dataset|England          |Northern Europe |Not Socially Engaged|1      |1   |1        |1        |null             |null      |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |null        |(not provided)|organic|null        |google  |1496242202|1          |1496242202    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |www.googlemerchandisestore.com/home                                                               |www.googlemerchandisestore.com/home                                       |0          |www.googlemerchandisestore.com/home                                       |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |www.googlemerchandisestore.com |/home                                      |/home            |              |              |              |Google Online Store                                |null          |null         |null        |null       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Organic Search |[EMEA]         |20170531|Chrome |not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Windows        |not available in demo dataset|not available in demo dataset|not available in demo dataset|7457135857298103204|(not set)  |not available in demo dataset|Europe   |Netherlands   |not available in demo dataset|not available in demo dataset|(not set)                        |hp.net           |not available in demo dataset|(not set)        |Western Europe  |Not Socially Engaged|1      |1   |1        |1        |null             |null      |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |null        |(not provided)|organic|null        |google  |1496227837|1          |1496227837    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |www.googlemerchandisestore.com/home                                                               |www.googlemerchandisestore.com/home                                       |0          |www.googlemerchandisestore.com/home                                       |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |www.googlemerchandisestore.com |/home                                      |/home            |              |              |              |Google Online Store                                |null          |null         |null        |null       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# |Organic Search |[EMEA]         |20170531|Firefox|not available in demo dataset|not available in demo dataset|desktop       |not available in demo dataset|false   |not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|not available in demo dataset|Macintosh      |not available in demo dataset|not available in demo dataset|not available in demo dataset|4500406506454646175|Berlin     |not available in demo dataset|Europe   |Germany       |not available in demo dataset|not available in demo dataset|(not set)                        |t-ipconnect.de   |not available in demo dataset|Berlin           |Western Europe  |Not Socially Engaged|1      |1   |null     |1        |null             |null      |null                   |null              |null        |1     |null     |{null, not available in demo dataset, null, null, null, null}|(not set)|null        |true        |(not provided)|organic|null        |google  |1496240339|7          |1496240339    |null            |null         |null   |null        |null             |null               |null        |null           |null               |null        |null           |null          |null        |null          |null                              |null                                                |www.googlemerchandisestore.com/home                                                               |www.googlemerchandisestore.com/home                                       |0          |www.googlemerchandisestore.com/home                                       |(not set)    |(not set)    |(not set)    |(not set)    |(not set)    |null                    |null                    |null                    |(entrance)           |(entrance)           |(entrance)           |(entrance)           |(entrance)           |0          |null  |1   |null       |null         |null      |true   |null        |null         |null                |null              |null                   |null            |null            |null          |null        |null           |null                |null              |null              |www.googlemerchandisestore.com |/home                                      |/home            |              |              |              |Google Online Store                                |null          |null         |null        |null       |No                     | :                            |(not set)    |null       |null        |null                   |null                    |null               |null             |null         |null              |null               |null          |
# +---------------+---------------+--------+-------+-----------------------------+-----------------------------+--------------+-----------------------------+--------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------+-----------------------------+-----------------------------+-----------------------------+-------------------+-----------+-----------------------------+---------+--------------+-----------------------------+-----------------------------+---------------------------------+-----------------+-----------------------------+-----------------+----------------+--------------------+-------+----+---------+---------+-----------------+----------+-----------------------+------------------+------------+------+---------+-------------------------------------------------------------+---------+------------+------------+--------------+-------+------------+--------+----------+-----------+--------------+----------------+-------------+-------+------------+-----------------+-------------------+------------+---------------+-------------------+------------+---------------+--------------+------------+--------------+----------------------------------+----------------------------------------------------+--------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------+-----------+--------------------------------------------------------------------------+-------------+-------------+-------------+-------------+-------------+------------------------+------------------------+------------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-----------+------+----+-----------+-------------+----------+-------+------------+-------------+--------------------+------------------+-----------------------+----------------+----------------+--------------+------------+---------------+--------------------+------------------+------------------+-------------------------------+-------------------------------------------+-----------------+--------------+--------------+--------------+---------------------------------------------------+--------------+-------------+------------+-----------+-----------------------+------------------------------+-------------+-----------+------------+-----------------------+------------------------+-------------------+-----------------+-------------+------------------+-------------------+--------------+
# only showing top 10 rows

# %%
droplist = (
 'browser','browserSize','browserVersion','flashVersion','language','mobileDeviceBranding','mobileDeviceInfo','mobileDeviceMarketingName','mobileDeviceModel',
 'mobileInputSelector','screenColors','screenResolution','latitude','longitude','sessionQualityDim','adwordsClickInfo','campaign','keyword','screenDepth',
 'contentGroup1','contentGroup2','contentGroup3','contentGroup4','contentGroup5','previousContentGroup1','previousContentGroup2','previousContentGroup3','previousContentGroup4',
 'previousContentGroup5','option','step','domLatencyMetricsSample','pageDownloadTime','pageLoadSample','pageLoadTime','serverConnectionTime','speedMetricsSample',
 'hostname','pagePathLevel1','pagePathLevel2','pagePathLevel3','pagePathLevel4','searchKeyword','affiliation','currencyCode')

# %%
flatdf = flatdf.drop(*droplist)

# %% [markdown]
# **Stream through remaining columns and locate any that need to be drop with lack of information**

# %%
droplist2 = ('operatingSystemVersion','cityId','networkLocation','customDimensions','customMetrics','socialInteractionNetworkAction')

# %%
flatdf = flatdf.drop(*droplist2)

# %%
flatdf.show(n=5)
# Out:
# +---------------+---------------+--------+--------------+--------+---------------+-------------------+-----------+---------+-------------+--------------+---------------+-----------------+----------------+--------------------+-------+----+---------+---------+----------+-----------------------+------------------+------------+------+---------+------------+------------+------+------------+--------+----------+-----------+--------------+-------+------------+-----------------+-------------------+------------+---------------+-------------------+------------+---------------+--------------+----------+--------------+-----------------+-------------+--------------------+--------------------+--------------------+------------------------+------------------------+------------------------+-----------+-----------+-------------+----------+-------+-------------+--------------------+------------------+----------------+---------------+------------------+--------+---------+--------------+------------+-----------+-----------------------+-------------+-----------------------+------------------------+-------------------+-----------------+-------------+------------------+-------------------+--------------+
# |channelGrouping|          value|    date|deviceCategory|isMobile|operatingSystem|      fullVisitorId|       city|continent|      country|         metro|  networkDomain|           region|    subContinent|socialEngagementType|bounces|hits|newVisits|pageviews|timeOnSite|totalTransactionRevenue|transactionRevenue|transactions|visits|adContent|campaignCode|isTrueDirect|medium|referralPath|  source|   visitId|visitNumber|visitStartTime|isClick|isImpression|localProductPrice|localProductRevenue|productBrand|productListName|productListPosition|productPrice|productQuantity|productRevenue|productSKU|productVariant|v2ProductCategory|v2ProductName|      exitScreenName|   landingScreenName|          screenName|contentGroupUniqueViews1|contentGroupUniqueViews2|contentGroupUniqueViews3|action_type|eventAction|eventCategory|eventLabel|isFatal|transactionId|domContentLoadedTime|domInteractiveTime|domainLookupTime|redirectionTime|serverResponseTime|pagePath|pageTitle|searchCategory|promoIsClick|promoIsView|hasSocialSourceReferral|socialNetwork|localTransactionRevenue|localTransactionShipping|localTransactionTax|transactionCoupon|transactionId|transactionRevenue|transactionShipping|transactionTax|
# +---------------+---------------+--------+--------------+--------+---------------+-------------------+-----------+---------+-------------+--------------+---------------+-----------------+----------------+--------------------+-------+----+---------+---------+----------+-----------------------+------------------+------------+------+---------+------------+------------+------+------------+--------+----------+-----------+--------------+-------+------------+-----------------+-------------------+------------+---------------+-------------------+------------+---------------+--------------+----------+--------------+-----------------+-------------+--------------------+--------------------+--------------------+------------------------+------------------------+------------------------+-----------+-----------+-------------+----------+-------+-------------+--------------------+------------------+----------------+---------------+------------------+--------+---------+--------------+------------+-----------+-----------------------+-------------+-----------------------+------------------------+-------------------+-----------------+-------------+------------------+-------------------+--------------+
# |       Referral|[North America]|20170531|       desktop|   false|          Linux|5988717949752143819|   New York| Americas|United States|   New York NY|      (not set)|         New York|Northern America|Not Socially Engaged|   null|   5|     null|        5|        22|                   null|              null|        null|     1|     null|        null|        true|(none)|           /|(direct)|1496250487|          3|    1496250487|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|      null|          null|             null|         null|shop.googlemercha...|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|         null|                null|              null|            null|           null|              null|   /home|     Home|          null|        null|       true|                     No|    (not set)|                   null|                    null|               null|             null|         null|              null|               null|          null|
# |       Referral|             []|20170531|       desktop|   false|      Macintosh|1914206347497291855|  (not set)|     Asia|    Hong Kong|     (not set)| netvigator.com|        (not set)|    Eastern Asia|Not Socially Engaged|   null|   7|     null|        7|       348|                   null|              null|        null|     1|     null|        null|        true|(none)|           /|(direct)|1496242570|          7|    1496242570|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|      null|          null|             null|         null|shop.googlemercha...|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|         null|                null|              null|            null|           null|              null|   /home|     Home|          null|        null|       true|                     No|    (not set)|                   null|                    null|               null|             null|         null|              null|               null|          null|
# |       Referral|[North America]|20170531|       desktop|   false|      Macintosh|5688612779726117211|   New York| Americas|United States|   New York NY|      (not set)|         New York|Northern America|Not Socially Engaged|   null|   8|     null|        8|       207|                   null|              null|        null|     1|     null|        null|        null|(none)|           /|(direct)|1496268814|          2|    1496268814|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|      null|          null|             null|         null|shop.googlemercha...|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|         null|                null|              null|            null|           null|              null|   /home|     Home|          null|        null|       true|                     No|    (not set)|                   null|                    null|               null|             null|         null|              null|               null|          null|
# |         Direct|[South America]|20170531|       desktop|   false|        Windows|5995173173416756249|   Santa Fe| Americas|    Argentina|     (not set)|fibertel.com.ar|Santa Fe Province|   South America|Not Socially Engaged|   null|  10|     null|       10|       248|                   null|              null|        null|     1|     null|        null|        true|(none)|        null|(direct)|1496260952|          2|    1496260952|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|      null|          null|             null|         null|shop.googlemercha...|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|         null|                null|              null|            null|           null|              null|   /home|     Home|          null|        null|       true|                     No|    (not set)|                   null|                    null|               null|             null|         null|              null|               null|          null|
# |       Referral|[North America]|20170531|       desktop|   false|      Macintosh|5703962423814396269|Los Angeles| Americas|United States|Los Angeles CA|      (not set)|       California|Northern America|Not Socially Engaged|   null|  39|     null|       25|      2040|                   null|              null|        null|     1|     null|        null|        true|(none)|           /|(direct)|1496262254|         22|    1496262254|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|      null|          null|             null|         null|shop.googlemercha...|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|         null|                null|              null|            null|           null|              null|   /home|     Home|          null|        null|       true|                     No|    (not set)|                   null|                    null|               null|             null|         null|              null|               null|          null|
# +---------------+---------------+--------+--------------+--------+---------------+-------------------+-----------+---------+-------------+--------------+---------------+-----------------+----------------+--------------------+-------+----+---------+---------+----------+-----------------------+------------------+------------+------+---------+------------+------------+------+------------+--------+----------+-----------+--------------+-------+------------+-----------------+-------------------+------------+---------------+-------------------+------------+---------------+--------------+----------+--------------+-----------------+-------------+--------------------+--------------------+--------------------+------------------------+------------------------+------------------------+-----------+-----------+-------------+----------+-------+-------------+--------------------+------------------+----------------+---------------+------------------+--------+---------+--------------+------------+-----------+-----------------------+-------------+-----------------------+------------------------+-------------------+-----------------+-------------+------------------+-------------------+--------------+
# only showing top 5 rows

# %% [markdown]
# # **2.2.3: Drop unnesscary parenthesis and create key words for long repeating strings.**

# %%
flatdf = flatdf.withColumn('networkDomain', regexp_replace('networkDomain','[({ })]',""))\
.withColumn('value', regexp_replace('value','[ ]',""))\
.withColumn('city', regexp_replace('city','[({ })]',""))\
.withColumn('city', regexp_replace('city','notavailableindemodataset','NAID'))\
.withColumn('metro', regexp_replace('metro','not available in demo dataset','NAID'))\
.withColumn('metro', regexp_replace('metro','[({ })]',""))\
.withColumn('region', regexp_replace('region','[({ })]',""))\
.withColumn('region', regexp_replace('region','notavailableindemodataset','NAID'))\
.withColumn('socialEngagementType', regexp_replace('socialEngagementType','Not Socially Engaged','NSE'))\
.withColumn('medium',regexp_replace('medium','[({ })]',""))\
.withColumn('source',regexp_replace('source','[({ })]',""))\
.withColumn('productBrand',regexp_replace('productBrand','[({ })]',""))\
.withColumn('productVariant',regexp_replace('productVariant','[({ })]',""))\
.withColumn('socialNetwork',regexp_replace('socialNetwork','[({ })]',""))\
.withColumn('exitScreenName',regexp_replace('exitScreenName','www.',''))\
.withColumn('exitScreenName',regexp_replace('exitScreenName','.com',''))\
.withColumn('landingScreenName',regexp_replace('landingScreenName','www.',''))\
.withColumn('landingScreenName',regexp_replace('landingScreenName','.com',''))\
.withColumn('screenName',regexp_replace('screenName','www.',''))\
.withColumn('screenName',regexp_replace('screenName','.com',''))

# %%
droplist3 = ('subContinent','value','pagePath','productVariant','v2ProductCategory','continent','networkDomain','metro','region','socialEngagementType','screenName','searchCategory','isMobile','campaignCode','city','pageTitle','localTransactionRevenue','localTransactionShipping','localTransactionTax','transactionCoupon','transactionShipping','transactionTax','transactionId','transactionRevenue','v2ProductName')

# %%
flatdf = flatdf.drop(*droplist3)

# %%
flatdf.show()
# Out:
# +---------------+--------+--------------+---------------+-------------------+--------------+-------+----+---------+---------+----------+-----------------------+------------+------+--------------------+------------+---------+------------+--------+----------+-----------+--------------+-------+------------+-----------------+-------------------+------------+---------------+-------------------+------------+---------------+--------------+--------------+--------------------+--------------------+------------------------+------------------------+------------------------+-----------+-----------+-------------+----------+-------+--------------------+------------------+----------------+---------------+------------------+------------+-----------+-----------------------+-------------+
# |channelGrouping|    date|deviceCategory|operatingSystem|      fullVisitorId|       country|bounces|hits|newVisits|pageviews|timeOnSite|totalTransactionRevenue|transactions|visits|           adContent|isTrueDirect|   medium|referralPath|  source|   visitId|visitNumber|visitStartTime|isClick|isImpression|localProductPrice|localProductRevenue|productBrand|productListName|productListPosition|productPrice|productQuantity|productRevenue|    productSKU|      exitScreenName|   landingScreenName|contentGroupUniqueViews1|contentGroupUniqueViews2|contentGroupUniqueViews3|action_type|eventAction|eventCategory|eventLabel|isFatal|domContentLoadedTime|domInteractiveTime|domainLookupTime|redirectionTime|serverResponseTime|promoIsClick|promoIsView|hasSocialSourceReferral|socialNetwork|
# +---------------+--------+--------------+---------------+-------------------+--------------+-------+----+---------+---------+----------+-----------------------+------------+------+--------------------+------------+---------+------------+--------+----------+-----------+--------------+-------+------------+-----------------+-------------------+------------+---------------+-------------------+------------+---------------+--------------+--------------+--------------------+--------------------+------------------------+------------------------+------------------------+-----------+-----------+-------------+----------+-------+--------------------+------------------+----------------+---------------+------------------+------------+-----------+-----------------------+-------------+
# |       Referral|20170531|       desktop|          Linux|5988717949752143819| United States|   null|   5|     null|        5|        22|                   null|        null|     1|                null|        true|     none|           /|  direct|1496250487|          3|    1496250487|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|          null|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       true|                     No|       notset|
# |       Referral|20170531|       desktop|      Macintosh|1914206347497291855|     Hong Kong|   null|   7|     null|        7|       348|                   null|        null|     1|                null|        true|     none|           /|  direct|1496242570|          7|    1496242570|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|          null|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       true|                     No|       notset|
# |       Referral|20170531|       desktop|      Macintosh|5688612779726117211| United States|   null|   8|     null|        8|       207|                   null|        null|     1|                null|        null|     none|           /|  direct|1496268814|          2|    1496268814|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|          null|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       true|                     No|       notset|
# |         Direct|20170531|       desktop|        Windows|5995173173416756249|     Argentina|   null|  10|     null|       10|       248|                   null|        null|     1|                null|        true|     none|        null|  direct|1496260952|          2|    1496260952|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|          null|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       true|                     No|       notset|
# |       Referral|20170531|       desktop|      Macintosh|5703962423814396269| United States|   null|  39|     null|       25|      2040|                   null|        null|     1|                null|        true|     none|           /|  direct|1496262254|         22|    1496262254|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|          null|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       true|                     No|       notset|
# | Organic Search|20170531|       desktop|      Macintosh|1192333145578267748|        Canada|   null|  80|     null|       64|      4726|                   null|        null|     1|                null|        true|  organic|        null|  google|1496280352|          2|    1496280352|   null|        true|         16990000|               null|      notset|       Category|                  1|    16990000|           null|          null|  GGOEGAAX0104|shop.googlemercha...|shop.googlemercha...|                    null|                       1|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       null|                     No|       notset|
# |         Direct|20170531|        mobile|            iOS|0423250391712266292| United States|      1|   1|     null|        1|      null|                   null|        null|     1|                null|        true|     none|        null|  direct|1496242282|          2|    1496242282|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|          null|googlemerchandise...|googlemerchandise...|                    null|                    null|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       null|                     No|       notset|
# | Organic Search|20170531|        mobile|        Android|5476517208251322333|United Kingdom|      1|   1|        1|        1|      null|                   null|        null|     1|                null|        null|  organic|        null|  google|1496242202|          1|    1496242202|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|          null|googlemerchandise...|googlemerchandise...|                    null|                    null|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       null|                     No|       notset|
# | Organic Search|20170531|       desktop|        Windows|7457135857298103204|   Netherlands|      1|   1|        1|        1|      null|                   null|        null|     1|                null|        null|  organic|        null|  google|1496227837|          1|    1496227837|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|          null|googlemerchandise...|googlemerchandise...|                    null|                    null|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       null|                     No|       notset|
# | Organic Search|20170531|       desktop|      Macintosh|4500406506454646175|       Germany|      1|   1|     null|        1|      null|                   null|        null|     1|                null|        true|  organic|        null|  google|1496240339|          7|    1496240339|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|          null|googlemerchandise...|googlemerchandise...|                    null|                    null|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       null|                     No|       notset|
# | Organic Search|20170531|        mobile|            iOS|7168313220217771616| United States|      1|   1|        1|        1|      null|                   null|        null|     1|                null|        null|  organic|        null|  google|1496297699|          1|    1496297699|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|          null|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       true|                     No|       notset|
# | Organic Search|20170531|       desktop|      Macintosh|0143409417748642157| United States|      1|   1|     null|        1|      null|                   null|        null|     1|                null|        true|  organic|        null|  google|1496264881|          2|    1496264881|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|          null|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       true|                     No|       notset|
# |     Affiliates|20170531|       desktop|      Macintosh|3544756796260078052|         Spain|   null|   2|     null|        2|       680|                   null|        null|     1|                null|        null|affiliate|        null|Partners|1496262791|          2|    1496262791|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|          null|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       true|                     No|       notset|
# |       Referral|20170531|       desktop|      Macintosh|8131657665328866600| United States|   null|   3|     null|        3|        13|                   null|        null|     1|                null|        true|     none|           /|  direct|1496240656|          7|    1496240656|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|          null|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       null|                     No|       notset|
# |       Referral|20170531|       desktop|      Macintosh|0846224247814997578| United States|   null|   2|        1|        2|        16|                   null|        null|     1|                null|        null|     none|           /|  direct|1496250263|          1|    1496250263|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|          null|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       true|                     No|       notset|
# |    Paid Search|20170531|       desktop|      Macintosh|6558201378397181461| United States|   null|   2|        1|        2|        20|                   null|        null|     1|Google Merchandis...|        null|      cpc|        null|  google|1496265155|          1|    1496265155|   null|        null|             null|               null|        null|           null|               null|        null|           null|          null|          null|shop.googlemercha...|shop.googlemercha...|                    null|                    null|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       true|                     No|       notset|
# |       Referral|20170531|       desktop|      Macintosh|3332446057389437418|        Brazil|      1|   1|     null|        1|      null|                   null|        null|     1|                null|        true|     none|           /|  direct|1496257389|          2|    1496257389|   null|        true|        109990000|               null|      notset|       Category|                  1|   109990000|           null|          null|  GGOEGAAX0568|shop.googlemercha...|shop.googlemercha...|                    null|                       1|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       null|                     No|       notset|
# | Organic Search|20170531|        mobile|            iOS|7634634048096402934| United States|      1|   1|        1|        1|      null|                   null|        null|     1|                null|        null|  organic|        null|  google|1496272113|          1|    1496272113|   null|        true|          7990000|               null|      notset|       Category|                  1|     7990000|           null|          null|GGOEYDHJ019399|shop.googlemercha...|shop.googlemercha...|                    null|                       1|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       null|                     No|       notset|
# | Organic Search|20170531|        mobile|            iOS|4521137614052525797|        Russia|      1|   1|        1|        1|      null|                   null|        null|     1|                null|        null|  organic|        null|  google|1496240112|          1|    1496240112|   null|        true|          7990000|               null|      notset|       Category|                  1|     7990000|           null|          null|GGOEYDHJ019399|shop.googlemercha...|shop.googlemercha...|                    null|                       1|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       null|                     No|       notset|
# | Organic Search|20170531|        mobile|        Android|1694001894627709362|United Kingdom|      1|   1|     null|        1|      null|                   null|        null|     1|                null|        true|  organic|        null|  google|1496268633|          2|    1496268633|   null|        true|         16990000|               null|      notset|       Category|                  1|    16990000|           null|          null|GGOEWCKQ085457|shop.googlemercha...|shop.googlemercha...|                    null|                       1|                    null|          0|       null|         null|      null|   true|                null|              null|            null|           null|              null|        null|       null|                     No|       notset|
# +---------------+--------+--------------+---------------+-------------------+--------------+-------+----+---------+---------+----------+-----------------------+------------+------+--------------------+------------+---------+------------+--------+----------+-----------+--------------+-------+------------+-----------------+-------------------+------------+---------------+-------------------+------------+---------------+--------------+--------------+--------------------+--------------------+------------------------+------------------------+------------------------+-----------+-----------+-------------+----------+-------+--------------------+------------------+----------------+---------------+------------------+------------+-----------+-----------------------+-------------+
# only showing top 20 rows

# %%
flatdf.columns

# %%
flatdf.dtypes
# Out:
# [('channelGrouping', 'string'),
#  ('date', 'string'),
#  ('deviceCategory', 'string'),
#  ('operatingSystem', 'string'),
#  ('fullVisitorId', 'string'),
#  ('country', 'string'),
#  ('bounces', 'string'),
#  ('hits', 'string'),
#  ('newVisits', 'string'),
#  ('pageviews', 'string'),
#  ('timeOnSite', 'string'),
#  ('totalTransactionRevenue', 'string'),
#  ('transactions', 'string'),
#  ('visits', 'string'),
#  ('adContent', 'string'),
#  ('isTrueDirect', 'boolean'),
#  ('medium', 'string'),
#  ('referralPath', 'string'),
#  ('source', 'string'),
#  ('visitId', 'string'),
#  ('visitNumber', 'string'),
#  ('visitStartTime', 'string'),
#  ('isClick', 'boolean'),
#  ('isImpression', 'boolean'),
#  ('localProductPrice', 'string'),
#  ('localProductRevenue', 'string'),
#  ('productBrand', 'string'),
#  ('productListName', 'string'),
#  ('productListPosition', 'string'),
#  ('productPrice', 'string'),
#  ('productQuantity', 'string'),
#  ('productRevenue', 'string'),
#  ('productSKU', 'string'),
#  ('exitScreenName', 'string'),
#  ('landingScreenName', 'string'),
#  ('contentGroupUniqueViews1', 'string'),
#  ('contentGroupUniqueViews2', 'string'),
#  ('contentGroupUniqueViews3', 'string'),
#  ('action_type', 'string'),
#  ('eventAction', 'string'),
#  ('eventCategory', 'string'),
#  ('eventLabel', 'string'),
#  ('isFatal', 'boolean'),
#  ('domContentLoadedTime', 'string'),
#  ('domInteractiveTime', 'string'),
#  ('domainLookupTime', 'string'),
#  ('redirectionTime', 'string'),
#  ('serverResponseTime', 'string'),
#  ('promoIsClick', 'boolean'),
#  ('promoIsView', 'boolean'),
#  ('hasSocialSourceReferral', 'string'),
#  ('socialNetwork', 'string')]

# %% [markdown]
# # **2.2.4: Convert pyspark dataframe to pandas dataframe.

# %%
pandas_df = flatdf.to_pandas_on_spark()
# Out:
# WARNING:root:'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.

# %%
pandas_df.head()
# Out:
#   channelGrouping      date deviceCategory operatingSystem        fullVisitorId        country bounces hits newVisits pageviews timeOnSite totalTransactionRevenue transactions visits adContent isTrueDirect medium referralPath  source     visitId visitNumber visitStartTime isClick isImpression localProductPrice localProductRevenue productBrand productListName productListPosition productPrice productQuantity productRevenue productSKU                                                                                  exitScreenName                 landingScreenName contentGroupUniqueViews1 contentGroupUniqueViews2 contentGroupUniqueViews3 action_type eventAction eventCategory eventLabel  isFatal domContentLoadedTime domInteractiveTime domainLookupTime redirectionTime serverResponseTime promoIsClick  promoIsView hasSocialSourceReferral socialNetwork
# 0        Referral  20170531        desktop           Linux  5988717949752143819  United States    None    5      None         5         22                    None         None      1      None         True   none            /  direct  1496250487           3     1496250487    None         None              None                None         None            None                None         None            None           None       None                                                          shop.googlemerchandisestore/store.html  shop.googlemerchandisestore/home                     None                     None                     None           0        None          None       None     True                 None               None             None            None               None         None         True                      No        notset
# 1        Referral  20170531        desktop       Macintosh  1914206347497291855      Hong Kong    None    7      None         7        348                    None         None      1      None         True   none            /  direct  1496242570           7     1496242570    None         None              None                None         None            None                None         None            None           None       None                                              shop.googlemerchandisestore/google+redesign/office  shop.googlemerchandisestore/home                     None                     None                     None           0        None          None       None     True                 None               None             None            None               None         None         True                      No        notset
# 2        Referral  20170531        desktop       Macintosh  5688612779726117211  United States    None    8      None         8        207                    None         None      1      None         None   none            /  direct  1496268814           2     1496268814    None         None              None                None         None            None                None         None            None           None       None  shop.googlemerchandisestore/google+redesign/apparel/women+s+google+lightweight+microfleece.axd  shop.googlemerchandisestore/home                     None                     None                     None           0        None          None       None     True                 None               None             None            None               None         None         True                      No        notset
# 3          Direct  20170531        desktop         Windows  5995173173416756249      Argentina    None   10      None        10        248                    None         None      1      None         True   none         None  direct  1496260952           2     1496260952    None         None              None                None         None            None                None         None            None           None       None                          shop.googlemerchandisestore/google+redesign/office/writing+instruments  shop.googlemerchandisestore/home                     None                     None                     None           0        None          None       None     True                 None               None             None            None               None         None         True                      No        notset
# 4        Referral  20170531        desktop       Macintosh  5703962423814396269  United States    None   39      None        25       2040                    None         None      1      None         True   none            /  direct  1496262254          22     1496262254    None         None              None                None         None            None                None         None            None           None       None                                                         shop.googlemerchandisestore/basket.html  shop.googlemerchandisestore/home                     None                     None                     None           0        None          None       None     True                 None               None             None            None               None         None         True                      No        notset

# %% [markdown]
# **Change Data formats to match respective value**

# %%
df = pandas_df

# %%
df.dtypes
# Out:
# channelGrouping             object
# date                        object
# deviceCategory              object
# operatingSystem             object
# fullVisitorId               object
# country                     object
# bounces                     object
# hits                        object
# newVisits                   object
# pageviews                   object
# timeOnSite                  object
# totalTransactionRevenue     object
# transactions                object
# visits                      object
# adContent                   object
# isTrueDirect                  bool
# medium                      object
# referralPath                object
# source                      object
# visitId                     object
# visitNumber                 object
# visitStartTime              object
# isClick                       bool
# isImpression                  bool
# localProductPrice           object
# localProductRevenue         object
# productBrand                object
# productListName             object
# productListPosition         object
# productPrice                object
# productQuantity             object
# productRevenue              object
# productSKU                  object
# exitScreenName              object
# landingScreenName           object
# contentGroupUniqueViews1    object
# contentGroupUniqueViews2    object
# contentGroupUniqueViews3    object
# action_type                 object
# eventAction                 object
# eventCategory               object
# eventLabel                  object
# isFatal                       bool
# domContentLoadedTime        object
# domInteractiveTime          object
# domainLookupTime            object
# redirectionTime             object
# serverResponseTime          object
# promoIsClick                  bool
# promoIsView                   bool
# hasSocialSourceReferral     object
# socialNetwork               object
# dtype: object

# %%
int_list = ['fullVisitorId',
 'bounces',
 'hits',
 'newVisits',
 'pageviews',
 'totalTransactionRevenue',
 'transactions',
 'visits',
 'visitId',
 'visitNumber',
 'localProductPrice',
 'localProductRevenue',
 'productListPosition',
 'productPrice',
 'productQuantity',
 'productRevenue',
 'contentGroupUniqueViews1',
 'contentGroupUniqueViews2',
 'contentGroupUniqueViews3',
 'action_type',
 'promoIsClick',
 'promoIsView']

# %%
df[int_list] = df[int_list].astype(str).astype(int)

# %%
df.dtypes
# Out:
# channelGrouping             object
# date                        object
# deviceCategory              object
# operatingSystem             object
# fullVisitorId                int64
# country                     object
# bounces                      int64
# hits                         int64
# newVisits                    int64
# pageviews                    int64
# timeOnSite                  object
# totalTransactionRevenue      int64
# transactions                 int64
# visits                       int64
# adContent                   object
# isTrueDirect                  bool
# medium                      object
# referralPath                object
# source                      object
# visitId                      int64
# visitNumber                  int64
# visitStartTime              object
# isClick                       bool
# isImpression                  bool
# localProductPrice            int64
# localProductRevenue          int64
# productBrand                object
# productListName             object
# productListPosition          int64
# productPrice                 int64
# productQuantity              int64
# productRevenue               int64
# productSKU                  object
# exitScreenName              object
# landingScreenName           object
# contentGroupUniqueViews1     int64
# contentGroupUniqueViews2     int64
# contentGroupUniqueViews3     int64
# action_type                  int64
# eventAction                 object
# eventCategory               object
# eventLabel                  object
# isFatal                       bool
# domContentLoadedTime        object
# domInteractiveTime          object
# domainLookupTime            object
# redirectionTime             object
# serverResponseTime          object
# promoIsClick                 int64
# promoIsView                  int64
# hasSocialSourceReferral     object
# socialNetwork               object
# dtype: object

# %%
df.head(n=5)

# %% [markdown]
# Saved file a parquet on locacl google drive

# %%
df.to_parquet('/content/drive/MyDrive/df.parquet')
